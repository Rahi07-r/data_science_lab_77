# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahi07-r/data_science_lab_77/blob/main/odd_even.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter a number: "))

if (num % 2) == 0:
   print(f"{num} is an even number")
else:
   print(f"{num} is an odd number")
