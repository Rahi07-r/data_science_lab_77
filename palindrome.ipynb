# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahi07-r/data_science_lab_77/blob/main/palindrome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function to check if a number is a palindrome
def is_palindrome(number):
    # Convert the number to a string
    num_str = str(number)
    # Reverse the string
    reversed_str = num_str[::-1]
    # Compare the original and reversed strings
    if num_str == reversed_str:
        return True
    else:
        return False

# Get input from the user
try:
    user_input = int(input("Enter a number: "))

    # Check if it's a palindrome and print the result
    if is_palindrome(user_input):
        print(f"The number {user_input} is a palindrome.")
    else:
        print(f"The number {user_input} is not a palindrome.")
except ValueError:
    print("Invalid input. Please enter an integer.")
